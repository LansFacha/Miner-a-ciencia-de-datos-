# %% [markdown]
# BASE DE DATOS MINERIA 2001-2023
#
# Contexto: Esta base de datos contiene información sobre la producción y comercialización de materiales en distintos estados y municipios de México, registrada de forma mensual y anual.
# Su objetivo es permitir un análisis estadístico y exploratorio, ayudando a detectar patrones, variaciones y posibles áreas de mejora en la industria.
#
# Descripcion mgenerasl:
# *Se tiene un registrto mensual y anual de produccion.
# *Se incluyen datos geográficos (estado y municipio).
# *Información sobre tipo de productos, su volumen y estado del registro.
# *Se utilizaran graficas y modelos predictivos.
#
# | Columna          | Descripción breve                                     | Tipo de dato | Ejemplo         |
# |------------------|--------------------------------------------------------|--------------|-----------------|
# | COBERTURA        | Nivel geográfico del dato                              | str          | Estatal         |
# | ANIO             | Año en el que se registró la información                | int          | 2022            |
# | MES              | Mes en el que se registró la información                | str          | Marzo           |
# | ESTADO           | Estado de la República Mexicana                         | str          | Chihuahua       |
# | MUNICIPIO        | Municipio correspondiente                               | str          | Chihuahua       |
# | GRUPO_PRODUCTO   | Categoría general del producto                          | str          | Minerales no metálicos |
# | PRODUCTO         | Nombre específico del producto                          | str          | Arena           |
# | UNIDAD_MEDIDA    | Unidad en que se mide el volumen                        | str          | Toneladas       |
# | VOLUMEN          | Cantidad producida o comercializada                     | float        | 12500.50        |
# | ESTATUS          | Estado del registro                                     | str          | Activo          |

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ProduccionMinera_sucio.csv')
df
# Out:
#        COBERTURA    ANIO        MES                ESTADO  \
# 0      Municipal  2001.0      Enero       Baja California
# 1      Municipal  2001.0      Enero       Baja California
# 2      Municipal  2001.0      Enero       Baja California
# 3      Municipal  2001.0      Enero       Baja California
# 4      Municipal     NaN      Enero  Coahuila de Zaragoza
# ...          ...     ...        ...                   ...
# 95215  Municipal  2011.0  Diciembre               Jalisco
# 95216  Municipal  2017.0    Febrero                México
# 95217  Municipal  2008.0  Diciembre             Zacatecas
# 95218  Municipal  2011.0     Agosto               Jalisco
# 95219  Municipal  2015.0  Noviembre                México
#
#                      MUNICIPIO                    GRUPO_PRODUCTO  PRODUCTO  \
# 0                  Agua Prieta                 Metales Preciosos       Oro
# 1                  Agua Prieta                               NaN     Plata
# 2                  Agua Prieta  Metales Industriales No Ferrosos     Plomo
# 3                  Agua Prieta  Metales Industriales No Ferrosos     Cobre
# 4                  Agua Prieta            Minerales No Metálicos  Fluorita
# ...                        ...                               ...       ...
# 95215  San Sebastián del Oeste                 Metales Preciosos       Oro
# 95216                Zacualpan                 Metales Preciosos       Oro
# 95217            Chalchihuites                               NaN      Zinc
# 95218                  Cananea  Metales Industriales No Ferrosos     Plomo
# 95219              Zacazonapan  Metales Industriales No Ferrosos     Plomo
#
#       UNIDAD_MEDIDA  VOLUMEN              ESTATUS
# 0        Kilogramos    239.6  Cifras Definitivas.
# 1        Kilogramos   1642.0  Cifras Definitivas.
# 2         Toneladas      0.0  Cifras Definitivas.
# 3         Toneladas      0.0  Cifras Definitivas.
# 4         Toneladas   2430.0  Cifras Definitivas.
# ...             ...      ...                  ...
# 95215    Kilogramos      1.2  Cifras Definitivas.
# 95216    Kilogramos      1.0  Cifras Definitivas.
# 95217     Toneladas    216.0  Cifras Definitivas.
# 95218     Toneladas     15.0  Cifras Definitivas.
# 95219     Toneladas    724.0  Cifras Definitivas.
#
# [95220 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['COBERTURA', 'ANIO', 'MES', 'ESTADO', 'MUNICIPIO', 'GRUPO_PRODUCTO',
#        'PRODUCTO', 'UNIDAD_MEDIDA', 'VOLUMEN', 'ESTATUS'],
#       dtype='object')

# %%
df['COBERTURA'].unique()
# Out:
# array(['Municipal', nan, 'Auto%#'], dtype=object)

# %%
df.isnull().sum()
# Out:
# COBERTURA         2856
# ANIO              2856
# MES               2856
# ESTADO            2856
# MUNICIPIO         2856
# GRUPO_PRODUCTO    2856
# PRODUCTO          2856
# UNIDAD_MEDIDA     2856
# VOLUMEN           2856
# ESTATUS           2856
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5629)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# COBERTURA            0
# ANIO              2838
# MES               2821
# ESTADO            2846
# MUNICIPIO         2844
# GRUPO_PRODUCTO    2850
# PRODUCTO          2850
# UNIDAD_MEDIDA     2850
# VOLUMEN           2849
# ESTATUS           2850
# dtype: int64

# %%
df["COBERTURA"]=df["COBERTURA"].fillna("Municipal")
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\3845885672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["COBERTURA"]=df["COBERTURA"].fillna("Municipal")

# %%
df["GRUPO_PRODUCTO"].unique()
# Out:
# array(['Metales Preciosos', nan, 'Metales Industriales No Ferrosos',
#        'Minerales No Metálicos', 'Metales y Minerales Siderúrgicos',
#        'Auto%#'], dtype=object)

# %%
df['ESTADO'] = df['ESTADO'].fillna('Desconocido')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\2174859414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ESTADO'] = df['ESTADO'].fillna('Desconocido')

# %%
df['MES'] = df['MES'].fillna('Desconocido')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\3660040852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MES'] = df['MES'].fillna('Desconocido')

# %%
df['MUNICIPIO'] = df['MUNICIPIO'].fillna('Desconocido')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\2778744327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MUNICIPIO'] = df['MUNICIPIO'].fillna('Desconocido')

# %%
df['PRODUCTO'] = df['PRODUCTO'].fillna('Desconocido')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\4049714572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PRODUCTO'] = df['PRODUCTO'].fillna('Desconocido')

# %%
df['GRUPO_PRODUCTO'] = df['GRUPO_PRODUCTO'].fillna('Desconocido')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\3648830768.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GRUPO_PRODUCTO'] = df['GRUPO_PRODUCTO'].fillna('Desconocido')

# %%
moda = df['UNIDAD_MEDIDA'].mode()[0]

# %%
df['UNIDAD_MEDIDA'] = df['UNIDAD_MEDIDA'].fillna(moda)
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\2151742321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UNIDAD_MEDIDA'] = df['UNIDAD_MEDIDA'].fillna(moda)

# %%
moda1= df['VOLUMEN'].mode()[0]
df['VOLUMEN'] = df['VOLUMEN'].fillna(moda1)
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\393300732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VOLUMEN'] = df['VOLUMEN'].fillna(moda1)

# %%
moda2= df['ESTATUS'].mode()[0]
df['ESTATUS'] = df['ESTATUS'].fillna(moda2)
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\3104093569.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ESTATUS'] = df['ESTATUS'].fillna(moda2)

# %%
df['ANIO'] = pd.to_numeric(df['ANIO'], errors='coerce')
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\2230880612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANIO'] = pd.to_numeric(df['ANIO'], errors='coerce')

# %%
promedio = round(df['ANIO'].mean())
df['ANIO'] = df['ANIO'].fillna(promedio)
# Out:
# C:\Users\lansf\AppData\Local\Temp\ipykernel_27684\2007256104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANIO'] = df['ANIO'].fillna(promedio)

# %%
df = df.sort_values(by='ANIO').reset_index(drop=True)

# %%
df
# Out:
#        COBERTURA    ANIO          MES          ESTADO           MUNICIPIO  \
# 0      Municipal  2001.0        Enero         Durango              Centro
# 1      Municipal  2001.0  Desconocido         Durango  Concepción del Oro
# 2      Municipal  2001.0        Enero         Durango  Concepción del Oro
# 3      Municipal  2001.0        Enero         Durango  Concepción del Oro
# 4         Auto%#  2001.0        Enero         Durango              Aquila
# ...          ...     ...          ...             ...                 ...
# 89586  Municipal  2023.0    Diciembre         Durango             Mazapil
# 89587  Municipal  2023.0        Abril          Sonora    Jiménez del Teul
# 89588  Municipal  2023.0      Febrero  Aguascalientes         Agua Prieta
# 89589  Municipal  2023.0    Diciembre         Durango             Mazapil
# 89590  Municipal  2023.0    Diciembre         Durango     San Luis Potosí
#
#                          GRUPO_PRODUCTO     PRODUCTO UNIDAD_MEDIDA  VOLUMEN  \
# 0      Metales Industriales No Ferrosos         Zinc     Toneladas      1.0
# 1                     Metales Preciosos          Oro    Kilogramos      0.1
# 2                     Metales Preciosos        Plata    Kilogramos      0.0
# 3      Metales Industriales No Ferrosos        Plomo     Toneladas      5.0
# 4                     Metales Preciosos          Oro    Kilogramos      0.6
# ...                                 ...          ...           ...      ...
# 89586                 Metales Preciosos          Oro    Kilogramos    168.0
# 89587  Metales Industriales No Ferrosos         Zinc     Toneladas   1669.0
# 89588  Metales Industriales No Ferrosos        Cobre     Toneladas     48.0
# 89589                 Metales Preciosos  Desconocido    Kilogramos  13285.0
# 89590                 Metales Preciosos  Desconocido    Kilogramos    829.4
#
#                     ESTATUS
# 0       Cifras Definitivas.
# 1       Cifras Definitivas.
# 2       Cifras Definitivas.
# 3       Cifras Definitivas.
# 4       Cifras Definitivas.
# ...                     ...
# 89586  Cifras Preliminares.
# 89587  Cifras Preliminares.
# 89588  Cifras Preliminares.
# 89589  Cifras Preliminares.
# 89590  Cifras Preliminares.
#
# [89591 rows x 10 columns]

# %%
for col in df.columns:
    print(f"Columna: {col}")
    print(df[col].value_counts(dropna=False))
    print("-" * 40)
# Out:
# Columna: COBERTURA
# COBERTURA
# Municipal    87729
# Auto%#        1862
# Name: count, dtype: int64
# ----------------------------------------
# Columna: ANIO
# ANIO
# 2012.0    7062
# 2013.0    4435
# 2001.0    4236
# 2008.0    4101
# 2007.0    3997
# 2009.0    3990
# 2010.0    3982
# 2011.0    3969
# 2016.0    3944
# 2014.0    3934
# 2005.0    3882
# 2006.0    3836
# 2004.0    3674
# 2015.0    3664
# 2018.0    3611
# 2017.0    3604
# 2002.0    3514
# 2019.0    3443
# 2003.0    3404
# 2020.0    3373
# 2021.0    3333
# 2022.0    3306
# 2023.0    3297
# Name: count, dtype: int64
# ----------------------------------------
# Columna: MES
# MES
# Diciembre      7152
# Noviembre      7100
# Septiembre     7097
# Febrero        7093
# Octubre        7076
# Marzo          7075
# Julio          7075
# Junio          7071
# Mayo           7068
# Enero          7067
# Abril          7055
# Agosto         7011
# Desconocido    2821
# Auto%#         1830
# Name: count, dtype: int64
# ----------------------------------------
# Columna: ESTADO
# ESTADO
# Zacatecas                          13965
# Durango                            13598
# Chihuahua                          13491
# Sonora                              8304
# Sinaloa                             4522
# Jalisco                             3737
# San Luis Potosí                     3308
# Coahuila de Zaragoza                3183
# México                              3104
# Guerrero                            2887
# Michoacán de Ocampo                 2876
# Desconocido                         2846
# Hidalgo                             2361
# Oaxaca                              2130
# Querétaro                           1252
# Guanajuato                          1198
# Colima                              1060
# Aguascalientes                      1012
# Veracruz de Ignacio de la Llave      948
# Nayarit                              936
# Nuevo León                           780
# Tabasco                              571
# Baja California                      502
# Chiapas                              291
# Tamaulipas                           289
# Morelos                              169
# Baja California Sur                  156
# Puebla                               115
# Name: count, dtype: int64
# ----------------------------------------
# Columna: MUNICIPIO
# MUNICIPIO
# Centro                   4809
# Morelos                  4518
# Cosalá                   3927
# Chalchihuites            3481
# Agua Prieta              3295
#                          ...
# San Pedro de la Cueva      14
# Tonila                     13
# San Marcos                 13
# Tolimán                    12
# Zinapécuaro                12
# Name: count, Length: 92, dtype: int64
# ----------------------------------------
# Columna: GRUPO_PRODUCTO
# GRUPO_PRODUCTO
# Metales Preciosos                   41411
# Metales Industriales No Ferrosos    32142
# Minerales No Metálicos               5986
# Metales y Minerales Siderúrgicos     5352
# Desconocido                          2850
# Auto%#                               1850
# Name: count, dtype: int64
# ----------------------------------------
# Columna: PRODUCTO
# PRODUCTO
# Plata                   21694
# Oro                     19713
# Plomo                   12172
# Cobre                   11100
# Zinc                     8884
# Fierro en Extraccion     3626
# Azufre                   3181
# Desconocido              2850
# Auto%#                   1848
# Barita                   1752
# Pellets de fierro        1136
# Fluorita                 1055
# Coque                     580
# Name: count, dtype: int64
# ----------------------------------------
# Columna: UNIDAD_MEDIDA
# UNIDAD_MEDIDA
# Toneladas     46327
# Kilogramos    41421
# Auto%#         1843
# Name: count, dtype: int64
# ----------------------------------------
# Columna: VOLUMEN
# VOLUMEN
# 0.0        14913
# 1.0         2673
# 2.0         1399
# 3.0          871
# 0.1          550
#            ...
# 87712.0        1
# 8270.0         1
# 15805.0        1
# 2803.0         1
# 38183.0        1
# Name: count, Length: 17532, dtype: int64
# ----------------------------------------
# Columna: ESTATUS
# ESTATUS
# Cifras Definitivas.     86288
# Cifras Preliminares.     3303
# Name: count, dtype: int64
# ----------------------------------------

# %%
Mes={'Auto%#':'Desconocido'}

# %%
df['MES'] = df['MES'].replace(Mes)

# %%
df['COBERTURA']=df['COBERTURA'].replace(Mes)

# %%
df['GRUPO_PRODUCTO']=df['GRUPO_PRODUCTO'].replace(Mes)

# %%
df['PRODUCTO']=df['PRODUCTO'].replace(Mes)

# %%
df['UNIDAD_MEDIDA']=df['UNIDAD_MEDIDA'].replace(Mes)

# %%
df['COBERTURA'].unique()
# Out:
# array(['Municipal', 'Desconocido'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89591 entries, 0 to 89590
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   COBERTURA       89591 non-null  object
#  1   ANIO            89591 non-null  float64
#  2   MES             89591 non-null  object
#  3   ESTADO          89591 non-null  object
#  4   MUNICIPIO       89591 non-null  object
#  5   GRUPO_PRODUCTO  89591 non-null  object
#  6   PRODUCTO        89591 non-null  object
#  7   UNIDAD_MEDIDA   89591 non-null  object
#  8   VOLUMEN         89591 non-null  float64
#  9   ESTATUS         89591 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 6.8+ MB

# %%
df.isnull().sum()
# Out:
# COBERTURA         0
# ANIO              0
# MES               0
# ESTADO            0
# MUNICIPIO         0
# GRUPO_PRODUCTO    0
# PRODUCTO          0
# UNIDAD_MEDIDA     0
# VOLUMEN           0
# ESTATUS           0
# dtype: int64

# %%
df.to_csv("Base_limpia.csv", index=False)
